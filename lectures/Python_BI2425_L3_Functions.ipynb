# %% [markdown]
# # Functions
#
# Функции - обычный объект в питоне. И этот объект умеет 3 вещи:
# - Что-то принять в себя (аргументы)
# - Что-то сделать (тело функции)
# - Что-то вернуть на выход (результат)
#
# Все 3 вещи являются опциональными
#
# ![image.png](attachment:33892dea-40a6-4fdc-92ee-d63ce0a1e6a3.png)

# %%
var = 5

# %%
id(var)
# Out:
# 94817453654984

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
id(print)
# Out:
# 140555689105008

# %%
print()

# %%
var()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 var()
#
# TypeError: 'int' object is not callable

# %%
5()
# Out:
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# /tmp/ipykernel_26996/3302733713.py:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   5()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 5()
#
# TypeError: 'int' object is not callable

# %%
print(1)
# Out:
# 1

# %%
print('Hello', 'python')
# Out:
# Hello python

# %%
print('Hello', 'python', sep='_')
# Out:
# Hello_python

# %% [markdown]
# 1. Загуглить
# 2. Подсказки IDE shift+tab alt+tab alt+space
# 3. `help`

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
result = id(1)

# %%
result
# Out:
# 94817453654856

# %%
result = print(1)
# Out:
# 1

# %%
result

# %%
print(result)
# Out:
# None

# %%
type(result)
# Out:
# NoneType

# %% [markdown]
# #### Метод

# %%
result = '_'.join(['A', 'B', 'C'])

# %%
result
# Out:
# 'A_B_C'

# %%
my_list = [1, 2, 3] # 4

# %%
result = my_list.append(4)

# %%
print(result)
# Out:
# None

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %%
my_list = [1, 2, 3]
my_list = my_list.append(4)

# %%
print(my_list)
# Out:
# None

# %%
my_list = [1, 2, 3]
for i in [4, 5, 6]:
    my_list.append(i)

# %%
my_list
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
def my_func(a, b, c):
    ...
    ...
    ...

# %%
seq = 'ATCGTGCY'

# %%
def is_dna(seq):
    seq = seq.upper()
    if set(seq).issubset({'A', 'T', 'G', 'C'}): #  или <
        return print('Yes')
    else:
        return print('No')

def is_dna(seq):
    seq = seq.upper()
    if set(seq).issubset({'A', 'T', 'G', 'C'}): #  или <
        return True
    else:
        return False

def is_dna(seq):
    seq = seq.upper()
    if set(seq).issubset({'A', 'T', 'G', 'C'}): #  или <
        return True
    return False
    
def is_dna(seq):
    seq = seq.upper()
    return set(seq).issubset({'A', 'T', 'G', 'C'})

def is_not_dna(seq):
    seq = seq.upper()
    return not set(seq).issubset({'A', 'T', 'G', 'C'})

# %%
# Out:
# 6

# %%
def some_func():
    return sum([1,2,3])

# %%
result = some_func()
result
# Out:
# 6

# %%
result = is_dna('ATCGTGCY')

# %%
print(result)
# Out:
# No

# %% [markdown]
# ## Аргумент
# 1) Позиционные и именованные

# %%
def my_fun(a, b, c):
    return (a + b) * c

# %%
my_fun(1, 2, 3)
# Out:
# 9

# %%
my_fun(a=1, b=2, c=3)
# Out:
# 9

# %%
my_fun(a=1, c=2, b=3)
# Out:
# 8

# %%
def my_fun(a, b, c):
    return (a + b) * c

# %%
my_fun(1, c=2, b=3)
# Out:
# 8

# %%
my_fun(a=2, b=3, 1)
# Out:
#   Cell In[71], line 1
#     my_fun(a=2, b=3, 1)
#                       ^
# SyntaxError: positional argument follows keyword argument

# %%
print('A', 'B', sep='--')
# Out:
# A--B

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %% [markdown]
# 2) Аргументы с и без значением по умолчанию

# %%
def my_fun(a, b, c=3):
    return (a + b) * c

# %%
my_fun(1, 2, 4)
# Out:
# 12

# %%
my_fun(1, 2)
# Out:
# 9

# %%
my_fun(a=1, b=2)
# Out:
# 9

# %%
def my_fun(a, b, c=3):
    return (a + b) * c

# %%
my_fun(a=1, c=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 my_fun(a=1, c=2)
#
# TypeError: my_fun() missing 1 required positional argument: 'b'

# %%
def my_fun(a, b, c):
    return (a + b) * 3

# %%
def my_fun(a, b, c):
    print(c)
    c = 3 
    print(c)
    return (a + b) * c

# %%
my_fun(1, 2, 4)
# Out:
# 4
# 3
# 9

# %%
my_fun(1, 2, 3)
# Out:
# 9

# %%
def my_fun(a, b, c=3):
    return (a + b) * c

# %%
my_fun(1, 2, 4)
# Out:
# 12

# %%
my_fun(1, 2, 3)
# Out:
# 9

# %%
def my_fun(a, b, c=3):
    return (a + b) * c

# %%
my_fun(1, 2, 3)
# Out:
# 9

# %%
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 print(c)
#
# NameError: name 'c' is not defined

# %%
def my_fun(a, b):
    c = 3
    return (a + b) * c

# %%
my_fun(1,2)
# Out:
# 9

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
d = 5

def my_fun(a, b):
    c = 3
    print(d)
    return (a + b) * c

# %%
my_fun(1,2)
# Out:
# 5
# 9

# %%
c = 4
d = 5

def my_fun(a, b):
    c = 3
    print(c, d)
    return (a + b) * c

# %%
my_fun(1, 2)
# Out:
# 3 5
# 9

# %%
print(c)
# Out:
# 4

# %%
def my_fun(a, b, c):
    print(c)
    return (a + b) * c

# %%
my_fun(1, 2, 3)
# Out:
# 3
# 9

# %%
def my_fun(a, b, c=print(10)):
    print(c)
    return (a + b) * c
# Out:
# 10

# %%
my_fun(1, 2, 3)
# Out:
# 3
# 9

# %%
def add_to_list(value, my_list):
    my_list.append(value)
    return my_list

# %%
result = add_to_list(4, [1, 2, 3])

# %%
result
# Out:
# [1, 2, 3, 4]

# %%
def add_to_list(value, my_list=[]):
    my_list.append(value)
    return my_list

# %%
add_to_list(5)
# Out:
# [5]

# %%
add_to_list(6)
# Out:
# [5, 6]

# %% [markdown]
# # НЕ ИСПОЛЬЗУЙТЕ ИЗМЕНЯЕМЫЕ ТИПЫ ДАННЫХ В КАЧЕСТВЕ ЗНАЧЕНИЙ ПО УМОЛЧАНИЮ

# %%
def add_to_list(value, my_list=None):
    if my_list == None:
        my_list = []
    my_list.append(value)
    return my_list

def add_to_list(value, my_list=None):
    if my_list is None:
        my_list = []
    my_list.append(value)
    return my_list

# %%
add_to_list(4, [1, 2, 3])
# Out:
# [1, 2, 3, 4]

# %%
add_to_list(4)
# Out:
# [4]

# %%
add_to_list(5)
# Out:
# [5]
